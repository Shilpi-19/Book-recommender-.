# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpi-19/Book-recommender-./blob/main/neww.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X          0.0
# 1   276726  0155061224          5.0
# 2   276727  0446520802          0.0
# 3   276729  052165615X          3.0
# 4   276729  0521795028          6.0

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (43354, 8)
# (544365, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    1
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                               Book-Title  num_ratings
# 0       A Light in the Storm: The Civil War Diary of ...            4
# 1       Beyond IBM: Leadership Marketing and Finance ...            1
# 2       Final Fantasy Anthology: Official Strategy Gu...            4
# 3                                           It Takes Two            2
# 4       Q-Space (Star Trek The Next Generation, Book 47)            7
# ...                                                  ...          ...
# 40104                   why I'm like this : True Stories            8
# 40105                   Â¿QuiÃ©n se ha llevado mi queso?            1
# 40106                           Â¿QuÃ© me quieres, amor?            5
# 40107                              Ã?Â?ber die Freiheit.            1
# 40108                                     Ã?Â?bermorgen.            1
#
# [40109 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
# <ipython-input-15-ebeed7a91fd4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
#                                               Book-Title  avg_rating
# 0       A Light in the Storm: The Civil War Diary of ...       2.250
# 1       Beyond IBM: Leadership Marketing and Finance ...       0.000
# 2       Final Fantasy Anthology: Official Strategy Gu...       5.000
# 3                                           It Takes Two       0.000
# 4       Q-Space (Star Trek The Next Generation, Book 47)       0.000
# ...                                                  ...         ...
# 40104                   why I'm like this : True Stories       5.125
# ...

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                               Book-Title  num_ratings  \
# 0       A Light in the Storm: The Civil War Diary of ...            4
# 1       Beyond IBM: Leadership Marketing and Finance ...            1
# 2       Final Fantasy Anthology: Official Strategy Gu...            4
# 3                                           It Takes Two            2
# 4       Q-Space (Star Trek The Next Generation, Book 47)            7
# ...                                                  ...          ...
# 40104                   why I'm like this : True Stories            8
# 40105                   Â¿QuiÃ©n se ha llevado mi queso?            1
# 40106                           Â¿QuÃ© me quieres, amor?            5
# 40107                              Ã?Â?ber die Freiheit.            1
# 40108                                     Ã?Â?bermorgen.            1
#
#        avg_rating
# 0           2.250
# 1           0.000
# 2           5.000
# 3           0.000
# 4           0.000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                            Book-Title         Book-Author  \
# 0   Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 1    Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 4                                   The Da Vinci Code           Dan Brown
# 6                             The Secret Life of Bees       Sue Monk Kidd
# 10                The Red Tent (Bestselling Backlist)       Anita Diamant
# 11                          The Lovely Bones: A Novel        Alice Sebold
# 12  Where the Heart Is (Oprah's Book Club (Paperba...        Billie Letts
# 13                          Girl with a Pearl Earring     Tracy Chevalier
# 14                                           Timeline    MICHAEL CRICHTON
# 17                                         Life of Pi         Yann Martel
# 20                                Angels &amp; Demons           Dan Brown
# 24                                        The Summons        John Grisham
# ...

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'

# %% [markdown]
# # **Colaborative Filtering based Recommender**

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Prayer for Owen Meany                                0.0     0.0     0.0
# A Time to Kill                                         0.0     0.0     0.0
# Angels &amp; Demons                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Violets Are Blue                                       0.0     0.0     0.0
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     6.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores=cosine_similarity(pt)
similarity_scores.shape
# Out:
# (64, 64)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:4]
    data = []
    for i in similar_items:
        item=[]
        temp_df=books[books['Book-Title']==pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)
    return data

# %%
recommend("A Time to Kill")
# Out:
# [['The Street Lawyer',
#   'JOHN GRISHAM',
#   'http://images.amazon.com/images/P/0440225701.01.MZZZZZZZ.jpg'],
#  ['The Client',
#   'John Grisham',
#   'http://images.amazon.com/images/P/038542471X.01.MZZZZZZZ.jpg'],
#  ['The Rainmaker',
#   'JOHN GRISHAM',
#   'http://images.amazon.com/images/P/044022165X.01.MZZZZZZZ.jpg']]

# %%
pt.index[54]
# Out:
# 'The Street Lawyer'

# %%
import pickle #for exporting the model
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
popular_df
# Out:
#                                            Book-Title         Book-Author  \
# 0   Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 1    Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 4                                   The Da Vinci Code           Dan Brown
# 6                             The Secret Life of Bees       Sue Monk Kidd
# 10                The Red Tent (Bestselling Backlist)       Anita Diamant
# 11                          The Lovely Bones: A Novel        Alice Sebold
# 12  Where the Heart Is (Oprah's Book Club (Paperba...        Billie Letts
# 13                          Girl with a Pearl Earring     Tracy Chevalier
# 14                                           Timeline    MICHAEL CRICHTON
# 17                                         Life of Pi         Yann Martel
# 20                                Angels &amp; Demons           Dan Brown
# 24                                        The Summons        John Grisham
# ...

# %%
#import joblib

#joblib.dump(popular_df,'model-1')

# %%
#my_model = joblib.load('model-1')

# %%
#my_model
